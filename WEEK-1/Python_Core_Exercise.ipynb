# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0551-lgtm/NASSCOM-LAB/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):
    # Timestamp in the format YYYY-MM-DD HH:MM:SS
    timestamp_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Unique device ID
    device_id = f"DEV{i:03d}"

    # Randomly choose device type
    device_type = random.choice(DEVICE_TYPES)

    # Randomly choose location
    location = random.choice(LOCATIONS)

    # Generate random value based on device type
    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    # Create a tuple
    reading = (timestamp_str, device_id, device_type, location, value)

    # Add tuple to the list
    raw_sensor_data.append(reading)

# Print all sensor readings
print("\nGenerated Sensor Readings:")
for reading in raw_sensor_data:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# Generated Sensor Readings:
# ('2026-07-19 14:41:54', 'DEV001', 'Light_Sensor', 'Warehouse', 961.65)
# ('2026-07-19 14:41:54', 'DEV002', 'Pressure_Sensor', 'OfficeB', 1006.01)
# ('2026-07-19 14:41:54', 'DEV003', 'Humidity_Sensor', 'Lab2', 73.89)
# ('2026-07-19 14:41:54', 'DEV004', 'Humidity_Sensor', 'Warehouse', 41.47)
# ('2026-07-19 14:41:54', 'DEV005', 'Light_Sensor', 'Warehouse', 212.38)
# ('2026-07-19 14:41:54', 'DEV006', 'Temperature_Sensor', 'OfficeA', 22.62)
# ('2026-07-19 14:41:54', 'DEV007', 'Humidity_Sensor', 'Lab1', 42.28)
# ('2026-07-19 14:41:54', 'DEV008', 'Light_Sensor', 'OfficeB', 917.51)
# ('2026-07-19 14:41:54', 'DEV009', 'Light_Sensor', 'Lab2', 238.33)
# ('2026-07-19 14:41:54', 'DEV010', 'Temperature_Sensor', 'OfficeB', 26.02)
# ('2026-07-19 14:41:54', 'DEV011', 'Humidity_Sensor', 'Lab2', 62.87)
# ('2026-07-19 14:41:54', 'DEV012', 'Temperature_Sensor', 'OfficeB', 29.0)
# ('2026-07-19 14:41:54', 'DEV013', 'Humidity_Sensor', 'OfficeB', 73.96)
# ('2026-07-19 14:41:54', 'DEV014', 'Pressure_Sensor', 'Warehouse', 985.39)
# ('2026-07-19 14:41:54', 'DEV015', 'Pressure_Sensor', 'OfficeA', 984.98)
# ('2026-07-19 14:41:54', 'DEV016', 'Light_Sensor', 'Lab1', 653.18)
# ('2026-07-19 14:41:54', 'DEV017', 'Pressure_Sensor', 'Warehouse', 1012.44)
# ('2026-07-19 14:41:54', 'DEV018', 'Temperature_Sensor', 'Warehouse', 18.91)
# ('2026-07-19 14:41:54', 'DEV019', 'Pressure_Sensor', 'Lab1', 1010.74)
# ('2026-07-19 14:41:54', 'DEV020', 'Light_Sensor', 'OfficeA', 174.4)
# ('2026-07-19 14:41:54', 'DEV021', 'Humidity_Sensor', 'Warehouse', 76.83)
# ('2026-07-19 14:41:54', 'DEV022', 'Pressure_Sensor', 'Lab2', 1014.51)
# ('2026-07-19 14:41:54', 'DEV023', 'Temperature_Sensor', 'OfficeA', 25.27)
# ('2026-07-19 14:41:54', 'DEV024', 'Temperature_Sensor', 'Warehouse', 29.76)
# ('2026-07-19 14:41:54', 'DEV025', 'Pressure_Sensor', 'Lab2', 995.98)
# ('2026-07-19 14:41:54', 'DEV026', 'Humidity_Sensor', 'OfficeB', 59.64)
# ('2026-07-19 14:41:54', 'DEV027', 'Pressure_Sensor', 'OfficeA', 1020.29)
# ('2026-07-19 14:41:54', 'DEV028', 'Light_Sensor', 'OfficeA', 985.07)
# ('2026-07-19 14:41:54', 'DEV029', 'Light_Sensor', 'Warehouse', 393.14)
# ('2026-07-19 14:41:54', 'DEV030', 'Temperature_Sensor', 'OfficeA', 26.47)
# ('2026-07-19 14:41:54', 'DEV031', 'Temperature_Sensor', 'Lab2', 25.32)
# ('2026-07-19 14:41:54', 'DEV032', 'Pressure_Sensor', 'Warehouse', 986.53)
# ('2026-07-19 14:41:54', 'DEV033', 'Light_Sensor', 'OfficeA', 774.2)
# ('2026-07-19 14:41:54', 'DEV034', 'Temperature_Sensor', 'OfficeA', 21.55)
# ('2026-07-19 14:41:54', 'DEV035', 'Temperature_Sensor', 'OfficeA', 24.78)
# ('2026-07-19 14:41:54', 'DEV036', 'Pressure_Sensor', 'Lab2', 1016.98)
# ('2026-07-19 14:41:54', 'DEV037', 'Pressure_Sensor', 'OfficeB', 996.65)
# ('2026-07-19 14:41:54', 'DEV038', 'Pressure_Sensor', 'Warehouse', 987.16)
# ('2026-07-19 14:41:54', 'DEV039', 'Temperature_Sensor', 'Lab1', 23.3)
# ('2026-07-19 14:41:54', 'DEV040', 'Light_Sensor', 'Lab2', 480.58)
# ('2026-07-19 14:41:54', 'DEV041', 'Temperature_Sensor', 'Lab2', 19.86)
# ('2026-07-19 14:41:54', 'DEV042', 'Humidity_Sensor', 'Lab2', 47.96)
# ('2026-07-19 14:41:54', 'DEV043', 'Light_Sensor', 'Warehouse', 579.25)
# ('2026-07-19 14:41:54', 'DEV044', 'Light_Sensor', 'Warehouse', 840.21)
# ('2026-07-19 14:41:54', 'DEV045', 'Light_Sensor', 'OfficeB', 768.82)
# ('2026-07-19 14:41:54', 'DEV046', 'Humidity_Sensor', 'Lab1', 75.99)
# ('2026-07-19 14:41:54', 'DEV047', 'Humidity_Sensor', 'Lab1', 77.47)
# ('2026-07-19 14:41:54', 'DEV048', 'Light_Sensor', 'OfficeA', 836.46)
# ('2026-07-19 14:41:54', 'DEV049', 'Temperature_Sensor', 'OfficeA', 28.02)
# ('2026-07-19 14:41:54', 'DEV050', 'Pressure_Sensor', 'OfficeB', 990.8)
# ('2026-07-19 14:41:54', 'DEV051', 'Light_Sensor', 'Lab1', 613.08)
# ('2026-07-19 14:41:54', 'DEV052', 'Light_Sensor', 'Lab2', 719.73)
# ('2026-07-19 14:41:54', 'DEV053', 'Pressure_Sensor', 'Warehouse', 1014.36)
# ('2026-07-19 14:41:54', 'DEV054', 'Humidity_Sensor', 'Lab1', 67.06)
# ('2026-07-19 14:41:54', 'DEV055', 'Humidity_Sensor', 'OfficeB', 79.08)
# ('2026-07-19 14:41:54', 'DEV056', 'Humidity_Sensor', 'Warehouse', 59.6)
# ('2026-07-19 14:41:54', 'DEV057', 'Temperature_Sensor', 'Lab1', 18.08)
# ('2026-07-19 14:41:54', 'DEV058', 'Light_Sensor', 'OfficeB', 268.4)
# ('2026-07-19 14:41:54', 'DEV059', 'Temperature_Sensor', 'Warehouse', 25.34)
# ('2026-07-19 14:41:54', 'DEV060', 'Temperature_Sensor', 'OfficeB', 21.45)
# ('2026-07-19 14:41:54', 'DEV061', 'Temperature_Sensor', 'Warehouse', 24.81)
# ('2026-07-19 14:41:54', 'DEV062', 'Temperature_Sensor', 'OfficeB', 21.39)
# ('2026-07-19 14:41:54', 'DEV063', 'Temperature_Sensor', 'Lab2', 18.32)
# ('2026-07-19 14:41:54', 'DEV064', 'Temperature_Sensor', 'Lab1', 22.6)
# ('2026-07-19 14:41:54', 'DEV065', 'Pressure_Sensor', 'Warehouse', 1007.33)
# ('2026-07-19 14:41:54', 'DEV066', 'Temperature_Sensor', 'Lab2', 24.02)
# ('2026-07-19 14:41:54', 'DEV067', 'Temperature_Sensor', 'OfficeA', 23.66)
# ('2026-07-19 14:41:54', 'DEV068', 'Pressure_Sensor', 'Lab2', 1026.68)
# ('2026-07-19 14:41:54', 'DEV069', 'Light_Sensor', 'Lab1', 214.83)
# ('2026-07-19 14:41:54', 'DEV070', 'Pressure_Sensor', 'Lab1', 985.41)
# ('2026-07-19 14:41:54', 'DEV071', 'Humidity_Sensor', 'Warehouse', 55.17)
# ('2026-07-19 14:41:54', 'DEV072', 'Humidity_Sensor', 'Warehouse', 45.26)
# ('2026-07-19 14:41:54', 'DEV073', 'Light_Sensor', 'Lab1', 628.87)
# ('2026-07-19 14:41:54', 'DEV074', 'Pressure_Sensor', 'Warehouse', 984.99)
# ('2026-07-19 14:41:54', 'DEV075', 'Humidity_Sensor', 'Lab1', 76.6)
# ('2026-07-19 14:41:54', 'DEV076', 'Humidity_Sensor', 'Warehouse', 32.54)
# ('2026-07-19 14:41:54', 'DEV077', 'Pressure_Sensor', 'OfficeA', 1008.67)
# ('2026-07-19 14:41:54', 'DEV078', 'Light_Sensor', 'OfficeB', 268.41)
# ('2026-07-19 14:41:54', 'DEV079', 'Pressure_Sensor', 'OfficeB', 983.16)
# ('2026-07-19 14:41:54', 'DEV080', 'Light_Sensor', 'Warehouse', 884.1)
# ('2026-07-19 14:41:54', 'DEV081', 'Humidity_Sensor', 'Lab1', 32.35)
# ('2026-07-19 14:41:54', 'DEV082', 'Light_Sensor', 'OfficeB', 467.32)
# ('2026-07-19 14:41:54', 'DEV083', 'Pressure_Sensor', 'OfficeA', 993.81)
# ('2026-07-19 14:41:54', 'DEV084', 'Pressure_Sensor', 'Lab2', 1008.13)
# ('2026-07-19 14:41:54', 'DEV085', 'Humidity_Sensor', 'Lab2', 39.94)
# ('2026-07-19 14:41:54', 'DEV086', 'Temperature_Sensor', 'OfficeA', 19.9)
# ('2026-07-19 14:41:54', 'DEV087', 'Humidity_Sensor', 'OfficeB', 61.2)
# ('2026-07-19 14:41:54', 'DEV088', 'Humidity_Sensor', 'Warehouse', 76.68)
# ('2026-07-19 14:41:54', 'DEV089', 'Pressure_Sensor', 'Warehouse', 1016.81)
# ('2026-07-19 14:41:54', 'DEV090', 'Humidity_Sensor', 'Warehouse', 79.14)
# ('2026-07-19 14:41:54', 'DEV091', 'Humidity_Sensor', 'Lab2', 30.49)
# ('2026-07-19 14:41:54', 'DEV092', 'Temperature_Sensor', 'Warehouse', 19.77)
# ('2026-07-19 14:41:54', 'DEV093', 'Pressure_Sensor', 'OfficeA', 1005.36)
# ('2026-07-19 14:41:54', 'DEV094', 'Light_Sensor', 'Warehouse', 438.66)
# ('2026-07-19 14:41:54', 'DEV095', 'Pressure_Sensor', 'OfficeA', 1019.12)
# ('2026-07-19 14:41:54', 'DEV096', 'Humidity_Sensor', 'Lab2', 74.44)
# ('2026-07-19 14:41:54', 'DEV097', 'Temperature_Sensor', 'OfficeA', 21.2)
# ('2026-07-19 14:41:54', 'DEV098', 'Pressure_Sensor', 'Lab2', 1010.8)
# ('2026-07-19 14:41:54', 'DEV099', 'Humidity_Sensor', 'Lab2', 40.92)
# ('2026-07-19 14:41:54', 'DEV100', 'Temperature_Sensor', 'Warehouse', 29.49)

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temp_dict = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp_dict)

# Print the temperature readings
print("\nTemperature Readings:")
for temp in temperature_readings:
    print(temp)
# Out:
# Temperature Readings:
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV006', 'location': 'OfficeA', 'temperature_celsius': 22.62}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV010', 'location': 'OfficeB', 'temperature_celsius': 26.02}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV012', 'location': 'OfficeB', 'temperature_celsius': 29.0}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV018', 'location': 'Warehouse', 'temperature_celsius': 18.91}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV023', 'location': 'OfficeA', 'temperature_celsius': 25.27}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV024', 'location': 'Warehouse', 'temperature_celsius': 29.76}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV030', 'location': 'OfficeA', 'temperature_celsius': 26.47}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV031', 'location': 'Lab2', 'temperature_celsius': 25.32}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV034', 'location': 'OfficeA', 'temperature_celsius': 21.55}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV035', 'location': 'OfficeA', 'temperature_celsius': 24.78}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV039', 'location': 'Lab1', 'temperature_celsius': 23.3}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV041', 'location': 'Lab2', 'temperature_celsius': 19.86}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV049', 'location': 'OfficeA', 'temperature_celsius': 28.02}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV057', 'location': 'Lab1', 'temperature_celsius': 18.08}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV059', 'location': 'Warehouse', 'temperature_celsius': 25.34}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV060', 'location': 'OfficeB', 'temperature_celsius': 21.45}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV061', 'location': 'Warehouse', 'temperature_celsius': 24.81}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV062', 'location': 'OfficeB', 'temperature_celsius': 21.39}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV063', 'location': 'Lab2', 'temperature_celsius': 18.32}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV064', 'location': 'Lab1', 'temperature_celsius': 22.6}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV066', 'location': 'Lab2', 'temperature_celsius': 24.02}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV067', 'location': 'OfficeA', 'temperature_celsius': 23.66}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV086', 'location': 'OfficeA', 'temperature_celsius': 19.9}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV092', 'location': 'Warehouse', 'temperature_celsius': 19.77}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV097', 'location': 'OfficeA', 'temperature_celsius': 21.2}
# {'timestamp': '2026-07-19 14:41:54', 'device_id': 'DEV100', 'location': 'Warehouse', 'temperature_celsius': 29.49}

# %%
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])   # Index 3 is the location

# Print the unique locations
print("\nUnique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'OfficeB', 'OfficeA', 'Lab2', 'Warehouse', 'Lab1'}

# %%
device_stats = {}

# Initialize the dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find the minimum and maximum values for each device type
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

# Display the results
print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(device, ":", stats)
# Out:
# Device Statistics:
# Temperature_Sensor : (18.08, 29.76)
# Humidity_Sensor : (30.49, 79.14)
# Pressure_Sensor : (983.16, 1026.68)
# Light_Sensor : (174.4, 985.07)

# %%
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
sample_string = "PythonProgrammingIsFun"
# Extract elements from the 10th to the 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

# Print the results
print("\nReadings from 10th to 20th (inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# Readings from 10th to 20th (inclusive):
# ('2026-07-19 14:41:54', 'DEV010', 'Temperature_Sensor', 'OfficeB', 26.02)
# ('2026-07-19 14:41:54', 'DEV011', 'Humidity_Sensor', 'Lab2', 62.87)
# ('2026-07-19 14:41:54', 'DEV012', 'Temperature_Sensor', 'OfficeB', 29.0)
# ('2026-07-19 14:41:54', 'DEV013', 'Humidity_Sensor', 'OfficeB', 73.96)
# ('2026-07-19 14:41:54', 'DEV014', 'Pressure_Sensor', 'Warehouse', 985.39)
# ('2026-07-19 14:41:54', 'DEV015', 'Pressure_Sensor', 'OfficeA', 984.98)
# ('2026-07-19 14:41:54', 'DEV016', 'Light_Sensor', 'Lab1', 653.18)
# ('2026-07-19 14:41:54', 'DEV017', 'Pressure_Sensor', 'Warehouse', 1012.44)
# ('2026-07-19 14:41:54', 'DEV018', 'Temperature_Sensor', 'Warehouse', 18.91)
# ('2026-07-19 14:41:54', 'DEV019', 'Pressure_Sensor', 'Lab1', 1010.74)
# ('2026-07-19 14:41:54', 'DEV020', 'Light_Sensor', 'OfficeA', 174.4)
#
# Every 5th reading:
# ('2026-07-19 14:41:54', 'DEV001', 'Light_Sensor', 'Warehouse', 961.65)
# ('2026-07-19 14:41:54', 'DEV006', 'Temperature_Sensor', 'OfficeA', 22.62)
# ('2026-07-19 14:41:54', 'DEV011', 'Humidity_Sensor', 'Lab2', 62.87)
# ('2026-07-19 14:41:54', 'DEV016', 'Light_Sensor', 'Lab1', 653.18)
# ('2026-07-19 14:41:54', 'DEV021', 'Humidity_Sensor', 'Warehouse', 76.83)
# ('2026-07-19 14:41:54', 'DEV026', 'Humidity_Sensor', 'OfficeB', 59.64)
# ('2026-07-19 14:41:54', 'DEV031', 'Temperature_Sensor', 'Lab2', 25.32)
# ('2026-07-19 14:41:54', 'DEV036', 'Pressure_Sensor', 'Lab2', 1016.98)
# ('2026-07-19 14:41:54', 'DEV041', 'Temperature_Sensor', 'Lab2', 19.86)
# ('2026-07-19 14:41:54', 'DEV046', 'Humidity_Sensor', 'Lab1', 75.99)
# ('2026-07-19 14:41:54', 'DEV051', 'Light_Sensor', 'Lab1', 613.08)
# ('2026-07-19 14:41:54', 'DEV056', 'Humidity_Sensor', 'Warehouse', 59.6)
# ('2026-07-19 14:41:54', 'DEV061', 'Temperature_Sensor', 'Warehouse', 24.81)
# ('2026-07-19 14:41:54', 'DEV066', 'Temperature_Sensor', 'Lab2', 24.02)
# ('2026-07-19 14:41:54', 'DEV071', 'Humidity_Sensor', 'Warehouse', 55.17)
# ('2026-07-19 14:41:54', 'DEV076', 'Humidity_Sensor', 'Warehouse', 32.54)
# ('2026-07-19 14:41:54', 'DEV081', 'Humidity_Sensor', 'Lab1', 32.35)
# ('2026-07-19 14:41:54', 'DEV086', 'Temperature_Sensor', 'OfficeA', 19.9)
# ('2026-07-19 14:41:54', 'DEV091', 'Humidity_Sensor', 'Lab2', 30.49)
# ('2026-07-19 14:41:54', 'DEV096', 'Humidity_Sensor', 'Lab2', 74.44)

# %%
# Extract the substring "Programming"
substring_1 = sample_string[6:17]

# Extract the reverse of "Python" -> "nohtyP"
substring_2 = sample_string[5::-1]

# Print the results
print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %%
# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

# Print the results
print("\n5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Light_Sensor
# Device Type Suffix: Sensor

# %%
# 2.1 Function to get readings by location
print("\n--- Task 2: Function Definitions and Usage ---")

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# Example usage
location = "Lab1"
lab1_readings = get_readings_by_location(raw_sensor_data, location)

print(f"\nSensor Readings for {location}:")
for reading in lab1_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
#
# Sensor Readings for Lab1:
# ('2026-07-19 14:41:54', 'DEV007', 'Humidity_Sensor', 'Lab1', 42.28)
# ('2026-07-19 14:41:54', 'DEV016', 'Light_Sensor', 'Lab1', 653.18)
# ('2026-07-19 14:41:54', 'DEV019', 'Pressure_Sensor', 'Lab1', 1010.74)
# ('2026-07-19 14:41:54', 'DEV039', 'Temperature_Sensor', 'Lab1', 23.3)
# ('2026-07-19 14:41:54', 'DEV046', 'Humidity_Sensor', 'Lab1', 75.99)
# ('2026-07-19 14:41:54', 'DEV047', 'Humidity_Sensor', 'Lab1', 77.47)
# ('2026-07-19 14:41:54', 'DEV051', 'Light_Sensor', 'Lab1', 613.08)
# ('2026-07-19 14:41:54', 'DEV054', 'Humidity_Sensor', 'Lab1', 67.06)
# ('2026-07-19 14:41:54', 'DEV057', 'Temperature_Sensor', 'Lab1', 18.08)
# ('2026-07-19 14:41:54', 'DEV064', 'Temperature_Sensor', 'Lab1', 22.6)
# ('2026-07-19 14:41:54', 'DEV069', 'Light_Sensor', 'Lab1', 214.83)
# ('2026-07-19 14:41:54', 'DEV070', 'Pressure_Sensor', 'Lab1', 985.41)
# ('2026-07-19 14:41:54', 'DEV073', 'Light_Sensor', 'Lab1', 628.87)
# ('2026-07-19 14:41:54', 'DEV075', 'Humidity_Sensor', 'Lab1', 76.6)
# ('2026-07-19 14:41:54', 'DEV081', 'Humidity_Sensor', 'Lab1', 32.35)

# %%
# 2.2 Function to calculate average temperature

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return round(average, 2)


# Example usage
avg_temperature = calculate_average_temperature(temperature_readings)

print("\nAverage Temperature:", avg_temperature)
# Out:
# Average Temperature: 23.5

# %%
# 2.3 Function to generate a formatted report line

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"


# Example usage
if len(temperature_readings) > 0:
    report = generate_report_line(temperature_readings[0])
    print("\nReport Line:")
    print(report)
# Out:
# Report Line:
# [2026-07-19 14:41:54] Device DEV006 at OfficeA: 22.62°C

# %%
# 3.1 Use the os module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.
print("\n--- Task 3: Core Library Usage ---")


reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.

# %%
# 3.2 Calculate the duration between the first and last timestamp

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string timestamps to datetime objects
    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    # Calculate duration
    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
# 3.3 Generate a list of 5 random integers between 100 and 200 (inclusive)

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [135, 166, 191, 145, 156]
